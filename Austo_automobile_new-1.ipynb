# %% [markdown]
# # **Austo Automobile Customer Analysis**

# %% [markdown]
# ### *** Context:***
#
# Austo Motor Company is a leading car manufacturer. They want to understand customer purchase behavior to improve marketing and customer satisfaction.

# %% [markdown]
# ### Objective:
# To analyze the automobile purchase dataset to answer key business questions and provide actionable insights for targeted marketing.

# %% [markdown]
# **Data Description**
# Age: The age of the individual in years.
#
# **Gender:** The gender of the individual, categorized as male or female.
#
# **Profession:** The occupation or profession of the individual.
#
# **Marital_status:** The marital status of the individual, such as married &, single
#
# **Education:** The educational qualification of the individual Graduate and Post Graduate
#
# **No_of_Dependents:** The number of dependents (e.g., children, elderly parents) that the individual supports financially.
#
# **Personal_loan:** A binary variable indicating whether the individual has taken a personal loan "Yes" or "No"
#
# **House_loan:** A binary variable indicating whether the individual has taken a housing loan "Yes" or "No"
#
# **Partner_working:** A binary variable indicating whether the individual's partner is employed "Yes" or "No"
#
# **Salary:** The individual's salary or income.
#
# **Partner_salary: **The salary or income of the individual's partner, if applicable.
#
# **Total_salary:** The total combined salary of the individual and their partner (if applicable).
#
# **Price:** The price of a product or service.
#
# **Make:** The type of automobile

# %% [markdown]
# Let us first import the necessary libraries before starting our analysis.

# %% [markdown]
# **Importing the libraries**

# %%
# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Command to tell Python to actually display the graphs
# %matplotlib inline

# %% [markdown]
# Connect google colab to google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Let us now load the dataset.

# %% [markdown]
# **Reading the datasets**

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Austo_Automobiles/austo_automobile.csv',encoding= 'unicode_escape')

# %% [markdown]
# **Data Overview**

# %% [markdown]
# 1)Observing the first few rows of the dataset
#
# 2)Getting information about the number of rows and columns
#
# 3)Finding out the data types of the columns
#
# 4)Checking the statistical summary

# %%
data.head()
# Out:
#    Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0   53    Male   Business        Married  Post Graduate                 4
# 1   53   Femal   Salaried        Married  Post Graduate                 4
# 2   53  Female   Salaried        Married  Post Graduate                 3
# 3   53  Female   Salaried        Married       Graduate                 2
# 4   53    Male   Salaried        Married  Post Graduate                 3
#
#   Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 0            No         No             Yes   99300         70700.0
# 1           Yes         No             Yes   95500         70300.0
# 2            No         No             Yes   97300         60700.0
# 3           Yes         No             Yes   72500         70300.0
# 4            No         No             Yes   79700         60200.0
#
#    Total_salary  Price Make
# 0        170000  61000  SUV
# 1        165800  61000  SUV
# 2        158000  57000  SUV
# ...

# %% [markdown]
# **Copy Data**

# %% [markdown]
# Let's make a copy of the original data and work on the copy so the original data remains safe

# %%
df=data.copy()

# %% [markdown]
# **Displaying the first 5 rows of the dataset**

# %%
df.head()
# Out:
#    Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0   53    Male   Business        Married  Post Graduate                 4
# 1   53   Femal   Salaried        Married  Post Graduate                 4
# 2   53  Female   Salaried        Married  Post Graduate                 3
# 3   53  Female   Salaried        Married       Graduate                 2
# 4   53    Male   Salaried        Married  Post Graduate                 3
#
#   Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 0            No         No             Yes   99300         70700.0
# 1           Yes         No             Yes   95500         70300.0
# 2            No         No             Yes   97300         60700.0
# 3           Yes         No             Yes   72500         70300.0
# 4            No         No             Yes   79700         60200.0
#
#    Total_salary  Price Make
# 0        170000  61000  SUV
# 1        165800  61000  SUV
# 2        158000  57000  SUV
# ...

# %% [markdown]
# **This data set contain information**
#
# The dataset includes information about customers' gender.
#
# The dataset contains details about customers' family background and salary-related information.

# %% [markdown]
# **Understanding the shape of the dataset**

# %%
df.shape
# Out:
# (1581, 14)

# %% [markdown]
# There are 1581 rows and 14 columns in the dataset.

# %% [markdown]
# **Checking the data types of the columns for the dataset**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1581 non-null   int64
#  1   Gender            1528 non-null   object
#  2   Profession        1581 non-null   object
#  3   Marital_status    1581 non-null   object
#  4   Education         1581 non-null   object
#  5   No_of_Dependents  1581 non-null   int64
#  6   Personal_loan     1581 non-null   object
#  7   House_loan        1581 non-null   object
#  8   Partner_working   1581 non-null   object
#  9   Salary            1581 non-null   int64
#  10  Partner_salary    1475 non-null   float64
#  11  Total_salary      1581 non-null   int64
#  12  Price             1581 non-null   int64
#  13  Make              1581 non-null   object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 173.1+ KB

# %% [markdown]
# The Age, No_of_Dependents , Salary,Partner salary and and Total salary columns are numerical columns while the rest are object Type.
#
# we can devide data into category at the basic  of Gender , Education ,Profession and Marital_status

# %% [markdown]
# **Getting the statistical summary for the dataset**

# %%
df.describe().T
# Out:
#                    count          mean           std      min      25%  \
# Age               1581.0     31.922201      8.425978     22.0     25.0
# No_of_Dependents  1581.0      2.457938      0.943483      0.0      2.0
# Salary            1581.0  60392.220114  14674.825044  30000.0  51900.0
# Partner_salary    1475.0  20225.559322  19573.149277      0.0      0.0
# Total_salary      1581.0  79625.996205  25545.857768  30000.0  60500.0
# Price             1581.0  35597.722960  13633.636545  18000.0  25000.0
#
#                       50%      75%       max
# Age                  29.0     38.0      54.0
# No_of_Dependents      2.0      3.0       4.0
# Salary            59500.0  71800.0   99300.0
# Partner_salary    25600.0  38300.0   80500.0
# Total_salary      78000.0  95900.0  171000.0
# Price             31000.0  47000.0   70000.0

# %% [markdown]
# **Age:**
#
# Average: 32 years
#
# Range: 22 to 54 years
#
# **Number of Dependents:**
#
# Average: 2.46
#
# Most have 2 to 3 dependents
#
# **Salary:**
#
# Individual Salary: Avg. $60,392 (Range: $30,000 – $99,300)
#
# Partner Salary: Avg. $20,226 (Many have $0 income; range up to $80,500)
#
# Total Household Salary: Avg. $79,626 (Range: $30,000 – $171,000)
#
# **Price:**
#
# Average: $35,598
#
# Range: $18,000 – $70,000

# %% [markdown]
# Now Check Duplicate Data The present in our file

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# which means there are zero duplicate rows in the DataFrame.

# %% [markdown]
# **Checking Missing Data In our File **

# %%
df.isnull().sum()
# Out:
# Age                   0
# Gender               53
# Profession            0
# Marital_status        0
# Education             0
# No_of_Dependents      0
# Personal_loan         0
# House_loan            0
# Partner_working       0
# Salary                0
# Partner_salary      106
# Total_salary          0
# Price                 0
# Make                  0
# dtype: int64

# %% [markdown]
# Based on the given response, data for two columns, Gender and Partner_salary, appears to be missing

# %% [markdown]
# Checking Gender Column values

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Femal', 'Female', nan, 'Femle'], dtype=object)

# %% [markdown]
# In the Gender column, there is some corrupted data. After analyzing the responses, it appears that "female" is misspelled in some rows (e.g., as "femal" or "femle").
#
# Let's check how many rows are affected by these incorrect spellings.

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      1199
# Female     327
# Femal        1
# Femle        1
# Name: count, dtype: int64

# %% [markdown]
# After analyzing the responses, it appears that "female" is misspelled as "femal" once and "femle" once. Let's correct these misspellings and include them in the "female" category.

# %%
df['Gender'] = df['Gender'].replace({
    'Femal': 'Female',
    'Femle': 'Female'
})

# %% [markdown]
# checking Again value cunt for gender

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      1199
# Female     329
# Name: count, dtype: int64

# %% [markdown]
# Now les't check how many null or missing value in gender column

# %%
df['Gender'].value_counts(dropna=False)
# Out:
# Gender
# Male      1199
# Female     329
# NaN         53
# Name: count, dtype: int64

# %% [markdown]
# Total 53 Values is missing in gender

# %% [markdown]
# Drop data from a file where gender is nan . because in subject it's given there is only 2 type of gender Male and Female

# %%
df = df.dropna(subset=['Gender'])

# %%
df['Gender'].value_counts(dropna=False)
# Out:
# Gender
# Male      1199
# Female     329
# Name: count, dtype: int64

# %% [markdown]
# Analysis Partner_salary missing values

# %%
df['Partner_salary'].value_counts(dropna=False)
# Out:
# Partner_salary
# 0.0        603
# NaN        103
# 40500.0     28
# 40200.0     27
# 40000.0     25
#           ...
# 22300.0      1
# 100.0        1
# 35200.0      1
# 35000.0      1
# 25600.0      1
# Name: count, Length: 148, dtype: int64

# %% [markdown]
# From the give response its show that there are some feildes that is nan

# %% [markdown]
# There is 103 row value is Nan For Partner_salary  so to fill a correct value at the place on nan we add a formula that is

# %% [markdown]
# **Total_Salary=salary+Partner_Salary**
# so lets add 1 more column that get the correct value of 103 missing  partner_salary

# %%
df['New_Partner_salary'] = df['Total_salary'] - df['Salary']

# %%
df['New_Partner_salary'].value_counts(dropna=False)
# Out:
# New_Partner_salary
# 0        690
# 40500     28
# 40200     27
# 40100     25
# 40000     25
#         ...
# 22300      1
# 100        1
# 35200      1
# 35000      1
# 25600      1
# Name: count, Length: 148, dtype: int64

# %% [markdown]
# Now remove Partner_salary column becouse we have a correct value in New_Partner_salary

# %%
df.drop('Partner_salary', axis=1, inplace=True)

# %% [markdown]
# Checking Missing Value Again

# %%
df.isnull().sum()
# Out:
# Age                   0
# Gender                0
# Profession            0
# Marital_status        0
# Education             0
# No_of_Dependents      0
# Personal_loan         0
# House_loan            0
# Partner_working       0
# Salary                0
# Total_salary          0
# Price                 0
# Make                  0
# New_Partner_salary    0
# dtype: int64

# %% [markdown]
# There Is no any missing value

# %% [markdown]
# **Now we have got a preliminary idea about the dataset. Let us now see the distribution of each of the columns to get a better understanding. Let us start with the numerical columns and use the histplot and boxplot to plot their distribution.**

# %%
sns.histplot(data=df, x="Age")
plt.xticks(ticks=range(20, 60, 5))
plt.show()

# %% [markdown]
# Based on the given histogram, the age range is between 23 and 54.  Most of the target audience or buyers are between 23 and 30 years old, indicating that this age group shows the highest interest in purchasing the product or service

# %% [markdown]
# **checkig outliers or Age**

# %%
sns.boxplot(data=df, x="Age")
plt.show()

# %% [markdown]
# There is no any outlire for age .Median of age is near to 29.

# %%
sns.histplot(data=df, x="No_of_Dependents")
plt.show()

# %% [markdown]
# From The given responce we can say that Average no of dependents are 2 -3

# %%
sns.boxplot(data=df, x="No_of_Dependents")
plt.show()

# %% [markdown]
# Majority of the customers come in groups of some people (0).
# 50% of the groups have 2 to 3 people in them.

# %%
sns.histplot(data=df, x="Salary")
plt.show()

# %% [markdown]
# From the Above response we can get that majority of the Employee Salary is in between to 50000 to 65000

# %%
sns.histplot(data=df, x="Total_salary")
plt.show()
sns.boxplot(data=df, x="Total_salary")
plt.show()

# %% [markdown]
# Distribution looks like almost evenly distributed with little skewness
# Yield per Total_salary of Persons has a right skewed distribution with a lot of outliers towards the higher end
# The median yield per colony is close to 8000 pounds

# %%
sns.histplot(data=df, x="Price")
plt.show()

# %%
sns.histplot(data=df, x="New_Partner_salary")
plt.show()
sns.boxplot(data=df, x="New_Partner_salary")
plt.show()

# %% [markdown]
# The dataset includes 700 people with non-working partners

# %% [markdown]
# **Treating the outlires of Total_salary**

# %%
def treat_outlire(df, col):
  Q1 = df[col].quantile(0.25)
  Q3 = df[col].quantile(0.75)
  IQR = Q3 - Q1
  lower_whisker = Q1 - 1.5 * IQR
  upper_whisker = Q3 + 1.5 * IQR
  df[col]=np.clip(df[col], lower_whisker, upper_whisker)
  return df

# %%
df=treat_outlire(df, 'Total_salary')

sns.boxplot(data=df, x="Total_salary")
plt.show()

# %% [markdown]
# **We have now seen the distribution of the numerical columns. Let us now move on to the categorical columns and use the countplot to see their distribution.**
#
# ---

# %% [markdown]
# Understanding the distribution of Gender

# %%
sns.countplot(data=df, x='Gender', hue='Gender');

# %% [markdown]
# The number of Male is more then Number of Female.
#
# Count of male is around 1200 and female is near 300
#
# so in purchse a service or a product male purchase more then women

# %%
sns.countplot(data=df, x='Profession', hue='Gender')
# Out:
# <Axes: xlabel='Profession', ylabel='count'>

# %% [markdown]
# from the given response we can get that most of the people are salaried employee
# for both the category in business man count is more than women

# %%
sns.countplot(data=df, x='Marital_status', hue='Gender');

# %%
sns.countplot(data=df, x='Marital_status', hue='No_of_Dependents');

# %% [markdown]
# **Bivariate Insights (Scatterplots):**

# %% [markdown]
# NO of dependes are more foa a married person

# %% [markdown]
# **Let's try to visualise how these numerical variables are associated with each other**

# %%
sns.scatterplot(data=df, x="Age", y="Price")
plt.show()

sns.scatterplot(data=df, x="Salary", y="Price")
plt.show()

# %% [markdown]
# **Age vs Price:**
# The scatterplot shows a trend where slightly older individuals (around 30–35) tend to spend more on vehicles. This could be due to greater financial stability or family needs.
#
# **Salary vs Price:**
# There's no strict linear trend, but higher salary brackets show a wider spread in car prices, indicating that while salary affects purchase power, personal preferences also play a role.

# %%
sns.scatterplot(data=df, x="Total_salary", y="Price")
plt.show()

# %% [markdown]
# :**Total_salary vs Price:**
# The total salary (probably combining household income) shows some positive relationship with price, though with noticeable variance — implying other factors like loans or family size could influence decision-making.

# %% [markdown]
# **Checking relation of home loan personal loan**

# %%
df[['Price', 'House_loan', 'Personal_loan']].corr()
# Out:
#                   Price  House_loan  Personal_loan
# Price          1.000000   -0.224322      -0.098795
# House_loan    -0.224322    1.000000       0.043482
# Personal_loan -0.098795    0.043482       1.000000

# %%
plt.subplot(1, 2, 1)
sns.boxplot(x='House_loan', y='Price', data=df)
plt.title('House Loan vs Price')

# Personal Loan vs Price
plt.subplot(1, 2, 2)
sns.boxplot(x='Personal_loan', y='Price', data=df)
plt.title('Personal Loan vs Price')

plt.tight_layout()
plt.show()

# %% [markdown]
# **House Loan vs Car Price**
# 0 = No House Loan, 1 = Has House Loan
#
# Median price for people without house loan (0) is higher than those with a house loan (1).
#
# Distribution is wider when no house loan — suggests more expensive cars purchased.
#
# **Personal Loan vs Car Price**
# Similar pattern: people without personal loans tend to buy higher-priced cars.
#
# Median price for group 0 (no loan) is slightly higher.

# %% [markdown]
# **Lets Compaire loan wit h salery who takes more loan **

# %%
plt.subplot(1, 2, 1)
sns.boxplot(x='House_loan', y='Salary', data=df)
plt.title('House Loan vs Salary')

# Personal Loan vs Salary
plt.subplot(1, 2, 2)
sns.boxplot(x='Personal_loan', y='Salary', data=df)
plt.title('Personal Loan vs Salary')

plt.tight_layout()
plt.show()

# %% [markdown]
# **House Loan vs Salary**
# Individuals without a house loan (0) tend to have a higher median salary and wider salary range.
#
# Those with a house loan (1) have lower median salaries, indicating that individuals with lower incomes may still opt for housing loans, possibly due to long-term investment goals or housing needs.
#
# **Personal Loan vs Salary**
# Similarly, individuals without a personal loan (0) tend to have slightly higher salaries than those with one.
#
# The difference is not as prominent as in the case of house loans, but it still shows that personal loans are more common among slightly lower-salaried individuals, perhaps for immediate financial needs.

# %%
sns.countplot(data=df, x='Marital_status', hue='House_loan');

# %% [markdown]
# Quesion 1:
# Do men tend to prefer SUVs more compared to women?

# %%
sns.countplot(data=df, x='Gender', hue='Make');

# %% [markdown]
# most of the **male like Hatchback** and **female like Suv**

# %% [markdown]
# Question 2:What is the likelihood of a salaried person buying a Sedan?

# %%
salaried_df = df[df['Profession'] == 'Salaried']
salaried_male_df = df[(df['Profession'] == 'Salaried') & (df['Gender'] == 'Male')]


salaried_sedan_pct = (salaried_df['Make'] == 'Sedan').mean()
# 3. Sheldon Cooper's claim: Compare SUV vs Sedan purchases among salaried males
salaried_male_counts = salaried_male_df['Make'].value_counts()
print(salaried_male_counts)
# Out:
# Make
# Sedan        279
# Hatchback    276
# SUV           85
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 4));
sns.barplot(x=salaried_male_counts.index, y=salaried_male_counts.values, palette="viridis");
plt.title("Vehicle Preference of Salaried Males");
plt.xlabel("Car Make");
plt.ylabel("Count");
plt.tight_layout();
plt.show();
# Out:
# <ipython-input-49-06b1b51788b5>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=salaried_male_counts.index, y=salaried_male_counts.values, palette="viridis");

# %% [markdown]
# MOST OF THE Mans that are salaried employee is like to purchase Sedan as compaire to suv

# %% [markdown]
# **Question 3**
# What evidence or data supports Sheldon Cooper's claim that a salaried male is an easier target for a SUV sale over a Sedan sale?

# %% [markdown]
# This data does not support Sheldon Cooper's claim. Sedans and Hatchbacks are far more popular among salaried males than SUVs.

# %% [markdown]
# **Question 4**:
# How does the the amount spent on purchasing automobiles vary by gender?

# %%
sns.boxplot(data=df, x='Price',y='Gender')
plt.title("Amount Spent on Automobiles by Gender")
plt.tight_layout()
plt.show()

# %% [markdown]
# Females tend to spend more on automobiles than males.
#
# The median purchase price is higher for females.
#
# Males have more extreme outliers, but their average or typical purchase is lower.

# %% [markdown]
# **Questin 5 **:
#  How much money was spent on purchasing automobiles by individuals who took a personal loan?

# %%
loan_total_spent = df[df['Personal_loan'] == 'Yes']['Price'].sum()
print(loan_total_spent)
# Out:
# 26644000

# %% [markdown]
# **Question 6**:
# How does having a working partner influence the purchase of higher-priced cars?

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Partner_working', y='Price')
plt.title("Car Prices vs Partner Working Status")
plt.tight_layout()
plt.show()

# Calculate mean and median for working vs non-working partner
partner_price_stats = df.groupby('Partner_working')['Price'].agg(['mean', 'median'])

# Output numeric insights
salaried_sedan_pct, salaried_male_counts, loan_total_spent, partner_price_stats
# Out:
# (np.float64(0.42824074074074076),
#  Make
#  Sedan        279
#  Hatchback    276
#  SUV           85
#  Name: count, dtype: int64,
#  np.int64(26644000),
#                           mean   median
#  Partner_working
#  No               36378.260870  32000.0
#  Yes              35730.310263  32000.0)

# %% [markdown]
# The median price is the same (₹31,000) in both groups.
#
# People without a working partner spend slightly more on average.

# %% [markdown]
# Relationship between Numerical coulmns

# %%
num_var = df.select_dtypes(include=['number']).columns
corr = df[num_var].corr()

plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# Age strongly influences car price: There's a strong positive relationship (0.8) between age and the price of a car, suggesting that older individuals tend to purchase more expensive vehicles.
#
# Total salary and new partner salary are closely linked: As expected, total salary and the new partner's salary show a high positive correlation (0.82), likely due to how total salary is calculated.
#
# Individual salary contributes to total earnings: There's a positive relationship between an individual's salary and their total salary.
#
# Price is driven by age and income: The price of a car has a notable positive correlation with age (0.8), total salary (0.36), and individual salary (0.41).
# Key Driver
#
# **Conclusion: Generally, individuals with higher incomes and those who are older are more inclined to buy expensive cars.**
